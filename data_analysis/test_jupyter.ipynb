# %%
# %matplotlib inline

# %%
from pylab import *

# %%
x = [1, 2, 3, 4]
y = [4, 5, 6, 7]

# %% [markdown]
# add the plot

# %%
figure()
plot(x, y, "r")
xlabel("x")
ylabel("y")
title('title')
show()
